# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.graphics.gofplots import qqplot
import matplotlib
matplotlib.use('TkAGG')
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

race_file_path = r"C:\Users\User\Desktop\IDAS\output_data_mustang.csv"

race_df = pd.read_csv(race_file_path)

race_df['LFtempCLF'] = race_df['LFtempCL'] * 9/5 + 32
race_df['LFtempCMF'] = race_df['LFtempCM'] * 9/5 + 32
race_df['LFtempCRF'] = race_df['LFtempCR'] * 9/5 + 32

race_df['LRtempCLF'] = race_df['LRtempCL'] * 9/5 + 32
race_df['LRtempCMF'] = race_df['LRtempCM'] * 9/5 + 32
race_df['LRtempCRF'] = race_df['LRtempCR'] * 9/5 + 32

race_df['RFtempCLF'] = race_df['RFtempCL'] * 9/5 + 32
race_df['RFtempCMF'] = race_df['RFtempCM'] * 9/5 + 32
race_df['RFtempCRF'] = race_df['RFtempCR'] * 9/5 + 32

race_df['RRtempCLF'] = race_df['RRtempCL'] * 9/5 + 32
race_df['RRtempCMF'] = race_df['RRtempCM'] * 9/5 + 32
race_df['RRtempCRF'] = race_df['RRtempCR'] * 9/5 + 32

lap_1_df = race_df[race_df['Lap'] == 1]

lap_2_df = race_df[race_df['Lap'] == 2]

lap_3_df = race_df[race_df['Lap'] == 3]

lap_4_df = race_df[race_df['Lap'] == 4]

lap_5_df = race_df[race_df['Lap'] == 5]

lap_25_df = race_df[race_df['Lap'] == 25]

def plot_tire_temp(df, plot_type, x, tire):

    x_var = df[f'{x}']

    if tire == 'lf':
        if plot_type == 'plot':

            plt.plot(x_var, df['LFtempCLF'], label='Left Carcass')
            plt.plot(x_var, df['LFtempCMF'], label='Middle Carcass')
            plt.plot(x_var, df['LFtempCRF'], label='Right Carcass')

            plt.title('Front Left Tire Temperature During Race')
            plt.xlabel(f'{x}')
            plt.ylabel('Temperature (F)')
            plt.legend()

            plt.show()
        
        elif plot_type == 'scatter':
            plt.scatter(x_var, df['LFtempCLF'], label='Left Carcass')
            plt.scatter(x_var, df['LFtempCMF'], label='Middle Carcass')
            plt.scatter(x_var, df['LFtempCRF'], label='Right Carcass')

            plt.title('Front Left Tire Temperature During Race')
            plt.xlabel(f'{x}')
            plt.ylabel('Temperature (F)')
            plt.legend()


            plt.show()

        else:
            print('Plot type not recognzed')
    
    elif tire == 'lr':
        if plot_type == 'plot':
            plt.plot(x_var, df['LRtempCLF'], label='Left Carcass')
            plt.plot(x_var, df['LRtempCMF'], label='Middle Carcass')
            plt.plot(x_var, df['LRtempCRF'], label='Right Carcass')

            plt.title('Rear Left Tire Temperature During Race')
            plt.xlabel(f'{x}')
            plt.ylabel('Temperature (F)')
            plt.legend()

            plt.show()
        
        elif plot_type == 'scatter':
            plt.scatter(x_var, df['LRtempCLF'], label='Left Carcass')
            plt.scatter(x_var, df['LRtempCMF'], label='Middle Carcass')
            plt.scatter(x_var, df['LRtempCRF'], label='Right Carcass')

            plt.title('Rear Left Tire Temperature During Race')
            plt.xlabel(f'{x}')
            plt.ylabel('Temperature (F)')
            plt.legend()


            plt.show()
        
        else:
            print('Plot type not recognzed')

    elif tire == 'rf':
        if plot_type == 'plot':
            plt.plot(x_var, df['RFtempCLF'], label='Left Carcass')
            plt.plot(x_var, df['RFtempCMF'], label='Middle Carcass')
            plt.plot(x_var, df['RFtempCRF'], label='Right Carcass')

            plt.title('Front Right Tire Temperature During Race')
            plt.xlabel(f'{x}')
            plt.ylabel('Temperature (F)')
            plt.legend()

            plt.show()
        
        elif plot_type == 'scatter':
            plt.scatter(x_var, df['RFtempCLF'], label='Left Carcass')
            plt.scatter(x_var, df['RFtempCMF'], label='Middle Carcass')
            plt.scatter(x_var, df['RFtempCRF'], label='Right Carcass')

            plt.title('Front Right Tire Temperature During Race')
            plt.xlabel(f'{x}')
            plt.ylabel('Temperature (F)')
            plt.legend()

            plt.show()

        else:
            print('Plot type not recognzed')

    elif tire == 'rr':
        if plot_type == 'plot':
            plt.plot(x_var, df['RRtempCLF'], label='Left Carcass')
            plt.plot(x_var, df['RRtempCMF'], label='Middle Carcass')
            plt.plot(x_var, df['RRtempCRF'], label='Right Carcass')

            plt.title('Rear Right Tire Temperature During Race')
            plt.xlabel(f'{x}')
            plt.ylabel('Temperature (F)')
            plt.legend()

            plt.show()
        
        elif plot_type == 'scatter':
            plt.scatter(x_var, df['RRtempCLF'], label='Left Carcass')
            plt.scatter(x_var, df['RRtempCMF'], label='Middle Carcass')
            plt.scatter(x_var, df['RRtempCRF'], label='Right Carcass')

            plt.title('Rear Right Tire Temperature During Race')
            plt.xlabel(f'{x}')
            plt.ylabel('Temperature (F)')
            plt.legend()

            plt.show()

        else:
            print('Plot type not recognzed')

    else:
        print('Tire not recognized')

def plot_carcass_temp(df, plot_type, x, carcass):

    x_var = df[f'{x}']

    if carcass == 'right':

        if plot_type == 'plot':


            plt.plot(x_var, df['RRtempCRF'], label='Right Rear Tire')
            plt.plot(x_var, df['RFtempCRF'], label='Right Front Tire')
            plt.plot(x_var, df['LRtempCRF'], label='Left Rear Tire')
            plt.plot(x_var, df['LFtempCRF'], label='Left Front Tire')

            plt.title('Right Carcass Temperatures')
            plt.xlabel(f'{x}')
            plt.ylabel('Temperature (F)')
            plt.legend()

            plt.xticks(range(int(min(x_var)), int(max(x_var)) + 1, 1))

            plt.show()
        
        elif plot_type == 'scatter':
            plt.scatter(x_var, df['RRtempCRF'], label='Right Rear Tire')
            plt.scatter(x_var, df['RFtempCRF'], label='Right Front Tire')
            plt.scatter(x_var, df['LRtempCRF'], label='Left Rear Tire')
            plt.scatter(x_var, df['LFtempCRF'], label='Left Front Tire')

            plt.title('Right Carcass Temperatures')
            plt.xlabel(f'{x}')
            plt.ylabel('Temperature (F)')
            plt.legend()

            plt.xticks(range(int(min(x_var)), int(max(x_var)) + 1, 1))

            plt.show()

        else:
            print('Plot type not recognized')

    elif carcass == 'middle':

        if plot_type == 'plot':
            plt.plot(x_var, df['RRtempCMF'], label='Right Rear Tire')
            plt.plot(x_var, df['RFtempCMF'], label='Right Front Tire')
            plt.plot(x_var, df['LRtempCMF'], label='Left Rear Tire')
            plt.plot(x_var, df['LFtempCMF'], label='Left Front Tire')

            plt.title('Middle Carcass Temperatures')
            plt.xlabel(f'{x}')
            plt.ylabel('Temperature (F)')
            plt.legend()

            plt.xticks(range(int(min(x_var)), int(max(x_var)) + 1, 1))

            plt.show()

        elif plot_type == 'scatter':
            plt.scatter(x_var, df['RRtempCMF'], label='Right Rear Tire')
            plt.scatter(x_var, df['RFtempCMF'], label='Right Front Tire')
            plt.scatter(x_var, df['LRtempCMF'], label='Left Rear Tire')
            plt.scatter(x_var, df['LFtempCMF'], label='Left Front Tire')

            plt.title('Middle Carcass Temperatures')
            plt.xlabel(f'{x}')
            plt.ylabel('Temperature (F)')
            plt.legend()

            plt.xticks(range(int(min(x_var)), int(max(x_var)) + 1, 1))

            plt.show()

        else:
            print('Plot type not recognized')

    elif carcass == 'left':

        if plot_type == 'plot':
            plt.plot(x_var, df['RRtempCLF'], label='Right Rear Tire')
            plt.plot(x_var, df['RFtempCLF'], label='Right Front Tire')
            plt.plot(x_var, df['LRtempCLF'], label='Left Rear Tire')
            plt.plot(x_var, df['LFtempCLF'], label='Left Front Tire')

            plt.title('Left Carcass Temperatures')
            plt.xlabel(f'{x}')
            plt.ylabel('Temperature (F)')
            plt.legend()

            plt.xticks(range(int(min(x_var)), int(max(x_var)) + 1, 1))

            plt.show()

        elif plot_type == 'scatter':
            plt.scatter(x_var, df['RRtempCLF'], label='Right Rear Tire')
            plt.scatter(x_var, df['RFtempCLF'], label='Right Front Tire')
            plt.scatter(x_var, df['LRtempCLF'], label='Left Rear Tire')
            plt.scatter(x_var, df['LFtempCLF'], label='Left Front Tire')

            plt.title('Left Carcass Temperatures')
            plt.xlabel(f'{x}')
            plt.ylabel('Temperature (F)')
            plt.legend()

            plt.xticks(range(int(min(x_var)), int(max(x_var)) + 1, 1))

            plt.show()

        else:
            print('Plot type not recognized')

    else:
        ('Carcass type not recognized')

# %%
def plot_tire_tread(df, plot_type, x, tire):

    x_var = df[f'{x}']

    if tire == 'lf':
        if plot_type == 'plot':

            plt.plot(x_var, df['LFwearL'], label='Left Carcass')
            plt.plot(x_var, df['LFwearM'], label='Middle Carcass')
            plt.plot(x_var, df['LFwearR'], label='Right Carcass')


            plt.title('Front Left Tire Tread Remaining During Race')
            plt.xlabel(f'{x}')
            plt.ylabel('Tread remaining (%)')
            plt.legend()

            plt.show()
        
        elif plot_type == 'scatter':
            plt.scatter(x_var, df['LFwearL'], label='Left Carcass')
            plt.scatter(x_var, df['LFwearM'], label='Middle Carcass')
            plt.scatter(x_var, df['LFwearR'], label='Right Carcass')

            plt.title('Front Left Tire Tread Remaining During Race')
            plt.xlabel(f'{x}')
            plt.ylabel('Tread remaining (%)')
            plt.legend()

            plt.show()

        else:
            print('Plot type not recognzed')
    
    elif tire == 'lr':
        if plot_type == 'plot':
            plt.plot(x_var, df['LRwearL'], label='Left Carcass')
            plt.plot(x_var, df['LRwearM'], label='Middle Carcass')
            plt.plot(x_var, df['LRwearR'], label='Right Carcass')


            plt.title('Rear Left Tire Temperature During Race')
            plt.xlabel(f'{x}')
            plt.ylabel('Tread remaining (%)')
            plt.legend()

            plt.show()
        
        elif plot_type == 'scatter':
            plt.scatter(x_var, df['LRwearL'], label='Left Carcass')
            plt.scatter(x_var, df['LRwearM'], label='Middle Carcass')
            plt.scatter(x_var, df['LRwearR'], label='Right Carcass')

            plt.title('Rear Left Tire Tread Remaining During Race')
            plt.xlabel(f'{x}')
            plt.ylabel('Tread remaining (%)')
            plt.legend()

            plt.show()
        
        else:
            print('Plot type not recognzed')

    elif tire == 'rf':
        if plot_type == 'plot':
            plt.plot(x_var, df['RFwearL'], label='Left Carcass')
            plt.plot(x_var, df['RFwearM'], label='Middle Carcass')
            plt.plot(x_var, df['RwearR'], label='Right Carcass')


            plt.title('Front Right Tire Tread Remaining During Race')
            plt.xlabel(f'{x}')
            plt.ylabel('Tread remaining (%)')
            plt.legend()

            plt.show()
        
        elif plot_type == 'scatter':
            plt.scatter(x_var, df['RFwearL'], label='Left Carcass')
            plt.scatter(x_var, df['RFwearM'], label='Middle Carcass')
            plt.scatter(x_var, df['RFwearR'], label='Right Carcass')

            plt.title('Front Right Tire Tread Remaining During Race')
            plt.xlabel(f'{x}')
            plt.ylabel('Tread remaining (%)')
            plt.legend()

            plt.show()


        else:
            print('Plot type not recognzed')

    elif tire == 'rr':
        if plot_type == 'plot':
            plt.plot(x_var, df['RRwearL'], label='Left Carcass')
            plt.plot(x_var, df['RRwearM'], label='Middle Carcass')
            plt.plot(x_var, df['RRwearR'], label='Right Carcass')

            plt.title('Rear Right Tire Tread Remaining During Race')
            plt.xlabel(f'{x}')
            plt.ylabel('Tread remaining (%)')
            plt.legend()

            plt.show()
        
        elif plot_type == 'scatter':
            plt.scatter(x_var, df['RRwearL'], label='Left Carcass')
            plt.scatter(x_var, df['RRwearM'], label='Middle Carcass')
            plt.scatter(x_var, df['RRwearR'], label='Right Carcass')

            plt.title('Rear Right Tire Tread Remaining During Race')
            plt.xlabel(f'{x}')
            plt.ylabel('Tread remaining (%)')
            plt.legend()

            plt.show()

        else:
            print('Plot type not recognzed')

    else:
        print('Tire not recognized')

# %%
plot_tire_temp(race_df, 'scatter', 'SessionTime', 'rf')

# %%
plot_tire_tread(race_df, 'scatter', 'Lap', 'rf')

# %%
plt.scatter(lap_3_df['LapCurrentLapTime'], lap_3_df['SteeringWheelAngle'])
plt.title('Steering Angle During Race')
plt.xlabel('SessionTime')
plt.ylabel('Angle(rad)')


plt.show()

# %%
plt.scatter(lap_25_df['LapCurrentLapTime'], lap_25_df['SteeringWheelAngle'])
plt.title('Steering Angle During Race')
plt.xlabel('SessionTime')
plt.ylabel('Angle(rad)')

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
